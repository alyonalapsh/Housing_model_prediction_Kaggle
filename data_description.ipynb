# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
train = pd.read_csv('data_housing_model/train.csv')

# %% [markdown]
# # Обзор данных

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %% [markdown]
# Id - идентификационный номер квартиры
#
# DistrictId - идентификационный номер района
#
# Rooms - количество комнат
#
# Square - площадь
#
# LifeSquare - жилая площадь
#
# KitchenSquare - площадь кухни
#
# Floor - этаж
#
# HouseFloor - количество этажей в доме
#
# HouseYear - год постройки дома
#
# Ecology_1, Ecology_2, Ecology_3 - экологические показатели местности
#
# Social_1, Social_2, Social_3 - социальные показатели местности
#
# Healthcare_1, Helthcare_2 - показатели местности, связанные с охраной здоровья
#
# Shops_1, Shops_2 - показатели, связанные с наличием магазинов, торговых центров
#
# Price (целевая переменная) - цена квартиры

# %% [markdown]
# # Характеристики

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [markdown]
# ## Поиск неверных данных

# %% [markdown]
# ### Сумма площади жилой и кухни больше чем общая

# %%
train[(train['LifeSquare']+train['KitchenSquare']>train['Square'])].head()
# Out:
#        Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 3    5809          58    2.0   53.352981   52.731512            9.0      8
# 28   8054          23    1.0   42.530043   43.967759            1.0      3
# 44  10521          38    3.0  104.211396  106.340403            0.0     20
# 48   7596          23    1.0   47.080100   46.807989           12.0      3
# 52   2301           1    2.0   61.400054   65.224603            0.0     17
#
#     HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 3         17.0       1977   0.437885         B         B        23      5735
# 28         9.0       2014   0.034656         B         B         0       168
# 44         0.0       2017   0.060753         B         B        15      2787
# 48         9.0       1977   0.014073         B         B         2       475
# 52        22.0       2016   0.007122         B         B         1       264
#
# ...

# %% [markdown]
# ### Ноль комнат

# %%
train[train['Rooms'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
train['Rooms'].value_counts()
# Out:
# Rooms
# 2.0     3880
# 1.0     3705
# 3.0     2235
# 4.0      150
# 5.0       18
# 0.0        8
# 10.0       2
# 19.0       1
# 6.0        1
# Name: count, dtype: int64

# %% [markdown]
# ### Ноль этажей в доме

# %%
train[train['HouseFloor'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7     11993          74    2.0   80.312926         NaN            0.0     14
# 23     6641          54    3.0  118.907612         NaN            0.0      2
# 26     4378          27    3.0  106.958871    0.641822            0.0     17
# 39     9371          23    2.0   60.503248         NaN            0.0     16
# 44    10521          38    3.0  104.211396  106.340403            0.0     20
# ...     ...         ...    ...         ...         ...            ...    ...
# 9707  12302          30    1.0   46.072913   48.307844            0.0      4
# 9769   9384          59    3.0   98.607328         NaN            0.0     14
# 9878  11441          62    2.0   71.985335   72.453232            0.0      5
# 9908   3171          62    1.0   35.873961         NaN            0.0     25
# 9944  16160          27    2.0   60.396765         NaN            0.0     10
#
# ...

# %% [markdown]
# ### Кол-во этажей в доме меньше чем указанный этаж

# %%
train[train['Floor']>train['HouseFloor']]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7     11993          74    2.0   80.312926         NaN            0.0     14
# 14    10953          27    1.0   53.769097   52.408027            1.0      5
# 16     2119          27    2.0   49.360648   31.993964            5.0      6
# 21    11935          27    2.0   64.711835         NaN            1.0     15
# 23     6641          54    3.0  118.907612         NaN            0.0      2
# ...     ...         ...    ...         ...         ...            ...    ...
# 9984   2237          52    3.0   64.074977   47.633428            6.0     11
# 9985  16159          27    1.0   38.968338         NaN            1.0     10
# 9989   4145          96    3.0   90.055233   47.860231           11.0     26
# 9991  11553           3    3.0  101.622794   51.628780           12.0     18
# 9995     77          32    2.0   50.401785   30.476203            5.0      6
#
# ...

# %% [markdown]
# ### Год постройки некорректный

# %%
pd.DataFrame(train['HouseYear'].value_counts()).reset_index().sort_values('HouseYear')
# Out:
#     HouseYear  count
# 95       1910      1
# 85       1912      2
# 93       1914      1
# 94       1916      1
# 83       1917      3
# ..        ...    ...
# 9        2018    175
# 43       2019     79
# 64       2020     19
# 92       4968      1
# 90   20052011      1
#
# [97 rows x 2 columns]

# %% [markdown]
# ### Пропущенные значения

# %%
train.isna().sum()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %% [markdown]
# ### Площадь квартиры меньше 13кв

# %%
train[train['Square'] < 13]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 212    1748          88    2.0  5.497061   67.628717            1.0     24
# 1316  11526          27    1.0  4.633498    1.969969            1.0     18
# 1608  10202           6    1.0  2.596351    4.604943            1.0      3
# 3280  10527          27    1.0  4.380726   40.805837            1.0     10
# 3413   9487           5    1.0  5.129222    5.549458            1.0      1
# 4853   3224          27    0.0  2.377248    0.873147            0.0      1
# 4900   4504          27    3.0  4.390331    5.610772            1.0      8
# 6392  14786           1    1.0  1.136859    4.525736            1.0      3
# 8030  13265           1    3.0  4.823679   79.767964            0.0      6
# 8283  15744          34    1.0  1.988943    2.642219            1.0     21
# 9294   6782          45    1.0  2.954309    5.257278            1.0      3
# ...

# %% [markdown]
# ### Жилая площадь меньше 8кв

# %%
train[train['LifeSquare'] < 8]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 26     4378          27    3.0  106.958871    0.641822            0.0     17
# 95     4280          34    2.0   61.334968    4.091945            1.0     26
# 134   12613           6    2.0   65.496674    5.589324            1.0      5
# 158   16779          27    3.0   51.991064    4.896202            1.0     22
# 160    3522           6    1.0   66.419841    3.987101            1.0      2
# ...     ...         ...    ...         ...         ...            ...    ...
# 9756  13583          27    2.0   58.943039    3.319486            1.0     11
# 9813   2040          62    1.0  122.438148    5.751401            1.0      2
# 9828  13630          24    3.0  127.141143    4.811405            1.0      3
# 9888   6053           6    1.0   41.314775    5.005477            1.0      9
# 9954    583          27    3.0   84.250710    4.187885            1.0     15
#
# ...

# %% [markdown]
# ### Площадь кухни меньше 4кв

# %%
train[train['KitchenSquare'] < 4]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2      4765          53    2.0  44.947953   29.197612            0.0      8
# 7     11993          74    2.0  80.312926         NaN            0.0     14
# 8      5172           1    2.0  64.511437         NaN            1.0      9
# 12     6452          13    2.0  54.522805   31.759753            1.0      8
# 14    10953          27    1.0  53.769097   52.408027            1.0      5
# ...     ...         ...    ...        ...         ...            ...    ...
# 9985  16159          27    1.0  38.968338         NaN            1.0     10
# 9986   2996           1    2.0  64.994245         NaN            1.0      9
# 9987  15623          23    2.0  55.620092         NaN            0.0      2
# 9994   4158          23    2.0  64.864198         NaN            1.0     17
# 9997   5123          27    1.0  47.939008         NaN            1.0     12
#
# ...

# %% [markdown]
# ### Нежилая площадь слишком большая

# %%
train[(train['Square']-(train['LifeSquare']+train['KitchenSquare'])) > (train['LifeSquare']+train['KitchenSquare'])]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 26     4378          27    3.0  106.958871    0.641822            0.0     17
# 95     4280          34    2.0   61.334968    4.091945            1.0     26
# 134   12613           6    2.0   65.496674    5.589324            1.0      5
# 158   16779          27    3.0   51.991064    4.896202            1.0     22
# 160    3522           6    1.0   66.419841    3.987101            1.0      2
# ...     ...         ...    ...         ...         ...            ...    ...
# 9756  13583          27    2.0   58.943039    3.319486            1.0     11
# 9813   2040          62    1.0  122.438148    5.751401            1.0      2
# 9828  13630          24    3.0  127.141143    4.811405            1.0      3
# 9888   6053           6    1.0   41.314775    5.005477            1.0      9
# 9954    583          27    3.0   84.250710    4.187885            1.0     15
#
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = train['Square'], y = train['Rooms'])
plt.xlabel("Square")
plt.ylabel("Rooms")
plt.title('Зависимость между площадью квартиры и количеством комнат')

plt.show()

# %% [markdown]
# На графике видно, что основная часть квартир имеет площадь до 200 кв.м при максимум 5-и комнатах.
#
# Значения, выпадающие из этого диапазона могут быть выбросами.

# %%
plt.hist(train['Square'], color = 'blue', edgecolor = 'black',
         bins = 30)
plt.yscale(value="log")
plt.xlabel("Square")
plt.ylabel("Number of apartments")
plt.title('Распределение площади квартир')
# Out:
# Text(0.5, 1.0, 'Распределение площади квартир')

# %%
plt.hist(train['Rooms'], color = 'blue', edgecolor = 'black',
         bins = 19)
plt.yscale(value="log")
plt.xlabel("Rooms")
plt.ylabel("Number of rooms")
plt.title('Распределение количества комнат')
# Out:
# Text(0.5, 1.0, 'Распределение количества комнат')
