# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import matplotlib
import matplotlib.image as img
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option("future.no_silent_downcasting", True)

# %%
train = pd.read_csv('data_housing_model/train.csv')

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %% [markdown]
# # Обработка данных

# %%
train = train.rename(columns={'LifeSquare': 'Life_Square', 'KitchenSquare': 'Kitchen_Square', 'HouseFloor': 'House_Floor', 'HouseYear': 'House_Year'})

# %% [markdown]
# ### Меняем кол-во комнат, равных 0, в зависимости от площади

# %%
train[train['Rooms'] == 0]
# Out:
#          Id  DistrictId  Rooms      Square  Life_Square  Kitchen_Square  \
# 1397  12638          27    0.0  138.427694   136.215499             0.0
# 1981   7917          27    0.0  212.932361   211.231125             0.0
# 2269   7317          27    0.0   41.790881          NaN             0.0
# 3911    770          28    0.0   49.483501          NaN             0.0
# 4366    456           6    0.0   81.491446          NaN             0.0
# 4853   3224          27    0.0    2.377248     0.873147             0.0
# 6149   3159          88    0.0   38.697117    19.345131             9.0
# 8834   9443          27    0.0   87.762616    85.125471             0.0
#
#       Floor  House_Floor  House_Year  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397      4          3.0        2016   0.075424         B         B        11
# 1981      2          3.0        2008   0.211401         B         B         9
# 2269     13          0.0        1977   0.211401         B         B         9
# 3911     16          0.0        2015   0.118537         B         B        30
# 4366      4          0.0        1977   0.243205         B         B         5
# 4853      1          0.0        1977   0.017647         B         B         2
# 6149      9         16.0        1982   0.127376         B         B        43
# 8834      5         15.0        1977   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1397      3097         0           NaN            0        0       B
# 1981      1892         0           NaN            0        1       B
# 2269      1892         0           NaN            0        1       B
# 3911      6207         1        1183.0            1        0       B
# 4366      1564         0         540.0            0        0       B
# 4853       469         0           NaN            0        0       B
# 6149      8429         3           NaN            3        9       B
# 8834      1892         0           NaN            0        1       B
#
#               Price
# 1397  268394.744389
# 1981  302211.260887
# 2269   98129.976788
# 3911  217009.338463
# 4366  212864.799112
# 4853  126596.941798
# 6149  158998.110646
# 8834  219281.918007

# %%
train.loc[(train.Square > 130) & (train.Rooms == 0), 'Rooms'] = 3
train.loc[((train.Square > 50) & (train.Square < 90)) & (train.Rooms == 0), 'Rooms'] = 2
train.loc[(train.Square < 50) & (train.Rooms == 0), 'Rooms'] = 1

# %%
train.groupby('Rooms', as_index=False).agg({'Id': 'count'}).rename(columns={'Id': 'count_of_rooms'})
# Out:
#    Rooms  count_of_rooms
# 0    1.0            3709
# 1    2.0            3882
# 2    3.0            2237
# 3    4.0             150
# 4    5.0              18
# 5    6.0               1
# 6   10.0               2
# 7   19.0               1

# %% [markdown]
# ### Меняем количество комнат в соответствии с площадью

# %%
train.groupby('Rooms', as_index=False).agg({'Square': 'mean'}).rename(columns={'Square': 'mean_square'})
# Out:
#    Rooms  mean_square
# 0    1.0    41.314395
# 1    2.0    56.802556
# 2    3.0    76.991546
# 3    4.0    98.377544
# 4    5.0   122.614941
# 5    6.0    59.414334
# 6   10.0    59.964120
# 7   19.0    42.006046

# %%
train.loc[(train.Rooms == 6), 'Rooms'] = 2
train.loc[(train.Rooms == 10), 'Rooms'] = 2
train.loc[(train.Rooms == 19), 'Rooms'] = 1

# %% [markdown]
# ### Удаляем две колонки из-за большого количества пропущенных значений

# %%
train.drop(['Life_Square', 'Kitchen_Square'], axis=1, inplace=True)

# %% [markdown]
# ### Меняем площадь в зависимости от кол-ва комнат (попробовать удалить)

# %%
train.groupby('Rooms', as_index=False).agg({'Square': 'mean'}).rename(columns={'Square': 'mean_square'})
# Out:
#    Rooms  mean_square
# 0    1.0    41.314582
# 1    2.0    56.804856
# 2    3.0    76.991546
# 3    4.0    98.377544
# 4    5.0   122.614941

# %%
train.loc[(train.Square < 13) & (train.Rooms == 1), 'Square'] = 41.314582
train.loc[(train.Square < 13) & (train.Rooms == 2), 'Square'] = 56.804856
train.loc[(train.Square < 13) & (train.Rooms == 3), 'Square'] = 76.991546

# %% [markdown]
# ### Меняем кол-во этажей в доме

# %%
train.loc[(train.House_Floor < train.Floor), 'House_Floor'] = train.Floor

# %% [markdown]
# ### Меняем год постройки

# %%
train.loc[(train.House_Year == 4968), 'House_Year'] = 1968

# %%
train.loc[(train.House_Year == 20052011), 'House_Year'] = 2005

# %% [markdown]
# ### Заменяем буквенное представление категориальных переменных на численное

# %%
train.replace({'A': 0, 'B': 1}, inplace=True)

# %% [markdown]
# ### Добавляем новые колонки на основе существующих

# %%
train['house_age'] = 2024-train['House_Year']

# %%
train.describe().T
# Out:
#                 count           mean           std           min  \
# Id            10000.0    8383.407700   4859.019020      0.000000
# DistrictId    10000.0      50.400800     43.587592      0.000000
# Rooms         10000.0       1.888100      0.811446      1.000000
# Square        10000.0      56.369596     20.986444     13.784865
# Floor         10000.0       8.526700      5.241148      1.000000
# House_Floor   10000.0      13.435700      6.094012      1.000000
# House_Year    10000.0    1984.865700     18.411517   1910.000000
# Ecology_1     10000.0       0.118858      0.119025      0.000000
# Social_1      10000.0      24.687000     17.532614      0.000000
# Social_2      10000.0    5352.157400   4006.799803    168.000000
# Social_3      10000.0       8.039200     23.831875      0.000000
# Healthcare_1   5202.0    1142.904460   1021.517264      0.000000
# Helthcare_2   10000.0       1.319500      1.493601      0.000000
# Shops_1       10000.0       4.231300      4.806341      0.000000
# Price         10000.0  214138.857399  92872.293865  59174.778028
# house_age     10000.0      39.134300     18.411517      4.000000
#
#                         25%            50%            75%            max
# Id              4169.500000    8394.500000   12592.500000   16798.000000
# DistrictId        20.000000      36.000000      75.000000     209.000000
# Rooms              1.000000       2.000000       2.000000       5.000000
# Square            41.782323      52.535436      65.912854     641.065193
# Floor              4.000000       7.000000      12.000000      42.000000
# House_Floor        9.000000      14.000000      17.000000     117.000000
# House_Year      1974.000000    1977.000000    2001.000000    2020.000000
# Ecology_1          0.017647       0.075424       0.195781       0.521867
# Social_1           6.000000      25.000000      36.000000      74.000000
# Social_2        1564.000000    5285.000000    7227.000000   19083.000000
# Social_3           0.000000       2.000000       5.000000     141.000000
# Healthcare_1     350.000000     900.000000    1548.000000    4849.000000
# Helthcare_2        0.000000       1.000000       2.000000       6.000000
# Shops_1            1.000000       3.000000       6.000000      23.000000
# Price         153872.633942  192269.644879  249135.462171  633233.466570
# house_age         23.000000      47.000000      50.000000     114.000000

# %%
train[['Floor', 'Social_1', 'Social_2', 'Social_3', 'Shops_1', 'house_age']] = train[['Floor', 'Social_1', 'Social_2', 'Social_3', 'Shops_1', 'house_age']].astype('float64')

# %%
train.set_index('Id', inplace=True)

# %%
train.drop('House_Year', axis=1, inplace=True)

# %%
train.drop('Healthcare_1', axis=1, inplace=True)

# %%
train.head()
# Out:
#        DistrictId  Rooms     Square  Floor  House_Floor  Ecology_1 Ecology_2  \
# Id
# 14038          35    2.0  47.981561    7.0          9.0   0.089040         1
# 15053          41    3.0  65.683640    7.0          9.0   0.000070         1
# 4765           53    2.0  44.947953    8.0         12.0   0.049637         1
# 5809           58    2.0  53.352981    8.0         17.0   0.437885         1
# 10783          99    1.0  39.649192   11.0         12.0   0.012339         1
#
#       Ecology_3  Social_1  Social_2  Social_3  Helthcare_2  Shops_1 Shops_2  \
# Id
# 14038         1      33.0    7976.0       5.0            0     11.0       1
# 15053         1      46.0   10309.0       1.0            1     16.0       1
# 4765          1      34.0    7759.0       0.0            1      3.0       1
# 5809          1      23.0    5735.0       3.0            0      5.0       1
# 10783         1      35.0    5776.0       1.0            2      4.0       1
#
#                Price  house_age
# Id
# 14038  184966.930730       55.0
# 15053  300009.450063       46.0
# 4765   220925.908524       56.0
# 5809   175616.227217       47.0
# 10783  150226.531644       48.0

# %%
y = train['Price']
y.head()
# Out:
# Id
# 14038    184966.930730
# 15053    300009.450063
# 4765     220925.908524
# 5809     175616.227217
# 10783    150226.531644
# Name: Price, dtype: float64

# %%
train.drop('Price', axis=1, inplace=True)

# %%
test = pd.read_csv('data_housing_model/test.csv')
test.rename(columns={'HouseFloor': 'House_Floor'}, inplace=True)

# %%
test.set_index('Id', inplace=True)
test.drop(['LifeSquare', 'KitchenSquare'], axis=1, inplace=True)
test.replace({'A': 0, 'B': 1}, inplace=True)
test['house_age'] = 2024-test['HouseYear']
test.drop('HouseYear', axis=1, inplace=True)
test.drop('Healthcare_1', axis=1, inplace=True)

# %%
test.head()
# Out:
#        DistrictId  Rooms     Square  Floor  House_Floor  Ecology_1 Ecology_2  \
# Id
# 725            58    2.0  49.882643      6         14.0   0.310199         1
# 15856          74    2.0  69.263183      6          1.0   0.075779         1
# 5480          190    1.0  13.597819      2          5.0   0.000000         1
# 15664          47    2.0  73.046609     22         22.0   0.101872         1
# 14275          27    1.0  47.527111     17         17.0   0.072158         1
#
#       Ecology_3  Social_1  Social_2  Social_3  Helthcare_2  Shops_1 Shops_2  \
# Id
# 725           1        11      2748         1            0        0       1
# 15856         1         6      1437         3            0        2       1
# 5480          1        30      7538        87            5        5       1
# 15664         1        23      4583         3            3        3       1
# 14275         1         2       629         1            0        0       0
#
#        house_age
# Id
# 725           52
# 15856         47
# 5480         115
# 15664         17
# 14275          7

# %% [markdown]
# # Стандартизация данных

# %%
train.dtypes
# Out:
# DistrictId       int64
# Rooms          float64
# Square         float64
# Floor          float64
# House_Floor    float64
# Ecology_1      float64
# Ecology_2       object
# Ecology_3       object
# Social_1       float64
# Social_2       float64
# Social_3       float64
# Helthcare_2      int64
# Shops_1        float64
# Shops_2         object
# house_age      float64
# dtype: object

# %%
feature_num_names = [
    'Rooms',
    'Square',
    'Floor',
    'House_Floor',
    'Ecology_1',
    'Social_1',
    'Social_2',
    'Social_3',
    'Shops_1',
    'house_age'
]

# %%
another_col = [
    'DistrictId',
    'Ecology_2',
    'Ecology_3',
    'Helthcare_2',
    'Shops_2'
]

# %%
scaler = StandardScaler()

# %%
train_standardized = pd.DataFrame(scaler.fit_transform(train[feature_num_names]),
                              columns=feature_num_names, index=train.index)

# %%
test_standardized = pd.DataFrame(scaler.transform(test[feature_num_names]),
                              columns=feature_num_names, index=test.index)

# %%
scaler2 = MinMaxScaler()
train_normalized = pd.DataFrame(scaler2.fit_transform(train[feature_num_names]), columns=feature_num_names,
                               index=train.index)

# %%
test_normalized = pd.DataFrame(scaler2.transform(test[feature_num_names]), columns=feature_num_names,
                               index=test.index)

# %%
scaler3 = RobustScaler()
train_scaled = pd.DataFrame(scaler3.fit_transform(train.loc[:, train.columns]), 
                            columns=train.columns, index=train.index)

# %%
test_scaled = pd.DataFrame(scaler3.transform(test), columns=test.columns, index=test.index)

# %%
train_standardized = pd.concat([train[another_col], train_standardized], axis=1)

# %%
test_standardized = pd.concat([test[another_col], test_standardized], axis=1)

# %%
train_normalized = pd.concat([train[another_col], train_normalized], axis=1)

# %%
test_normalized = pd.concat([test[another_col], test_normalized], axis=1)

# %%
train.to_csv('data_housing_model/train_housing_prepared')

# %%
test.to_csv('data_housing_model/test_housing_prepared')

# %%
train_standardized.to_csv('data_housing_model/train_standardized_housing_prepared')

# %%
test_standardized.to_csv('data_housing_model/test_standardized_housing_prepared')

# %%
train_normalized.to_csv('data_housing_model/train_normalized_housing_prepared')

# %%
test_normalized.to_csv('data_housing_model/test_normalized_housing_prepared')

# %%
train_scaled.to_csv('data_housing_model/train_scaled_housing_prepared')

# %%
test_scaled.to_csv('data_housing_model/test_scaled_housing_prepared')

# %%
y = pd.DataFrame(y)

# %%
y.to_csv('data_housing_model/housing_y')
